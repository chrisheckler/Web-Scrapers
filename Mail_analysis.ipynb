# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
import pickle

words = pd.read_table('outfile2.txt')

# %%
df = pd.DataFrame(words)

print(df)
# Out:
# Empty DataFrame
# ...
